# %%
import pandas as pd
movies_df = pd.read_csv('./master_list_greatest_films.csv')

# %%
movies_df.head()
# Out:
#      imdb_id  rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# 0  tt0000417            NaN            NaN            NaN           NaN
# 1  tt0000439            NaN            NaN            NaN           NaN
# 2  tt0004972            NaN             44            NaN           NaN
# 3  tt0006206            NaN            NaN            NaN           NaN
# 4  tt0006864             49            NaN            NaN           NaN
#
#   included_in_guardian_list included_in_1001_book  \
# 0                       NaN                  True
# 1                       NaN                  True
# 2                       NaN                  True
# 3                      True                  True
# 4                       NaN                  True
#
#                                               title  year      rated  \
# 0                                A Trip to the Moon  1902       TV-G
# 1                           The Great Train Robbery  1903       TV-G
# ...

# %%
movies_df.shape
# Out:
# (1211, 25)

# %%
movies_df.columns
# Out:
# Index([u'imdb_id', u'rank_afc_2007', u'rank_afc_1998', u'rank_wga_2005',
#        u'rank_ss_2012', u'included_in_guardian_list', u'included_in_1001_book',
#        u'title', u'year', u'rated', u'released', u'runtime', u'genre',
#        u'director', u'writer', u'actors', u'plot', u'language', u'country',
#        u'awards', u'poster', u'metascore', u'imdb_rating', u'imdb_votes',
#        u'alternate_title'],
#       dtype='object')

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1211 entries, 0 to 1210
# Data columns (total 25 columns):
# imdb_id                      1211 non-null object
# rank_afc_2007                100 non-null float64
# rank_afc_1998                100 non-null float64
# rank_wga_2005                101 non-null float64
# rank_ss_2012                 52 non-null float64
# included_in_guardian_list    179 non-null object
# included_in_1001_book        1177 non-null object
# title                        1211 non-null object
# year                         1211 non-null int64
# rated                        1076 non-null object
# released                     1188 non-null object
# runtime                      1210 non-null object
# genre                        1211 non-null object
# director                     1209 non-null object
# writer                       1179 non-null object
# actors                       1205 non-null object
# plot                         1204 non-null object
# ...

# %%
movies_df.describe()
# Out:
#        rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012         year  \
# count     100.000000     100.000000     101.000000     52.000000  1211.000000
# mean       50.500000      50.500000      51.000000     25.846154  1972.629232
# std        29.011492      29.011492      29.300171     14.601081    24.122904
# min         1.000000       1.000000       1.000000      1.000000  1902.000000
# 25%        25.750000      25.750000      26.000000     13.750000  1955.000000
# 50%        50.500000      50.500000      51.000000     26.000000  1974.000000
# 75%        75.250000      75.250000      76.000000     39.000000  1992.000000
# max       100.000000     100.000000     101.000000     50.000000  2014.000000
#
#         metascore  imdb_rating
# count  470.000000  1211.000000
# mean    79.823404     7.701239
# std     10.744597     0.544369
# min     47.000000     3.200000
# 25%     72.000000     7.400000
# 50%     81.000000     7.800000
# 75%     88.000000     8.100000
# ...

# %%
movies_df['year']
# Out:
# 0       1902
# 1       1903
# 2       1915
# 3       1915
# 4       1916
# 5       1919
# 6       1920
# 7       1920
# 8       1920
# 9       1921
# 10      1921
# 11      1922
# 12      1922
# 13      1922
# 14      1922
# 15      1922
# 16      1923
# 17      1923
# 18      1923
# 19      1924
# 20      1924
# 21      1925
# 22      1924
# 23      1926
# 24      1925
# 25      1925
# 26      1925
# 27      1925
# 28      1924
# 29      1925
#         ...
# 1181    2010
# 1182    2012
# 1183    2001
# 1184    2011
# 1185    2010
# 1186    2012
# 1187    2011
# 1188    1924
# 1189    2013
# 1190    2013
# 1191    2011
# 1192    2011
# 1193    2012
# 1194    2012
# 1195    2014
# 1196    2013
# 1197    2013
# 1198    2012
# 1199    2014
# 1200    2013
# 1201    2013
# 1202    2012
# 1203    2014
# 1204    2014
# 1205    2013
# 1206    2014
# 1207    2013
# 1208    2014
# 1209    2012
# 1210    2014
# Name: year, dtype: int64

# %%
movies_df[:3]
# Out:
#      imdb_id  rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# 0  tt0000417            NaN            NaN            NaN           NaN
# 1  tt0000439            NaN            NaN            NaN           NaN
# 2  tt0004972            NaN             44            NaN           NaN
#
#   included_in_guardian_list included_in_1001_book                    title  \
# 0                       NaN                  True       A Trip to the Moon
# 1                       NaN                  True  The Great Train Robbery
# 2                       NaN                  True    The Birth of a Nation
#
#    year      rated                      ...                       \
# 0  1902       TV-G                      ...
# 1  1903       TV-G                      ...
# 2  1915  NOT RATED                      ...
#
#                                               actors  \
# 0          Fran__ois Lallement, Jules-Eug_�ne Legris
# 1  A.C. Abadie, Gilbert M. 'Broncho Billy' Anders...
# ...

# %%
movies_df.ix[0:10, 'included_in_guardian_list']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3     True
# 4      NaN
# 5      NaN
# 6     True
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# Name: included_in_guardian_list, dtype: object

# %%
movies_df.query('rank_afc_2007 > 0 and rank_afc_1998 > 0 and rank_wga_2005 > 0 and rank_ss_2012 > 0 and included_in_guardian_list == True')
# Out:
#        imdb_id  rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# 146  tt0033467              1              1              4             2
# 321  tt0049730             12             96             97             7
# 362  tt0053291             22             14              9            42
# 375  tt0054215             14             18             92            35
# 564  tt0068646              2              3              2            21
# 601  tt0071562             32             32             10            31
# 663  tt0078788             30             28             55            14
#
#     included_in_guardian_list included_in_1001_book                   title  \
# 146                      True                  True            Citizen Kane
# 321                      True                  True           The Searchers
# 362                      True                  True        Some Like It Hot
# ...

# %%
movies_df.query('rank_afc_2007 > 0 and rank_afc_1998 > 0 and rank_wga_2005 > 0 and included_in_guardian_list == True')
# Out:
#        imdb_id  rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# 125  tt0031381              6              4             23           NaN
# 133  tt0032138             10              6             25           NaN
# 146  tt0033467              1              1              4             2
# 155  tt0034583              3              2              1           NaN
# 174  tt0036775             29             38             26           NaN
# 321  tt0049730             12             96             97             7
# 355  tt0053125             55             40             21           NaN
# 362  tt0053291             22             14              9            42
# 366  tt0053604             80             93             15           NaN
# 375  tt0054215             14             18             92            35
# 414  tt0057012             39             26             12           NaN
# 474  tt0061722             17              7             13           NaN
# ...

# %%
movies_df.query('rank_afc_2007 > 0 and rank_afc_1998 > 0 and rank_wga_2005 > 0')
# Out:
#        imdb_id  rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# 86   tt0025316             46             35             59           NaN
# 125  tt0031381              6              4             23           NaN
# 133  tt0032138             10              6             25           NaN
# 139  tt0032551             23             21             98           NaN
# 143  tt0032904             44             51             37           NaN
# 146  tt0033467              1              1              4             2
# 151  tt0033870             31             23             47           NaN
# 155  tt0034583              3              2              1           NaN
# 174  tt0036775             29             38             26           NaN
# 176  tt0036868             37             37             44           NaN
# 195  tt0038650             20             11             20           NaN
# 219  tt0040897             38             30             46           NaN
# ...

# %%
movies_df.groupby('director')

# %%
movies_df.groupby('director').count()['included_in_1001_book']
# Out:
# director
# Abbas Kiarostami                                                                             4
# Abdellatif Kechiche                                                                          1
# Abel Ferrara                                                                                 1
# Abel Gance                                                                                   2
# Abraham Polonsky                                                                             1
# Aditya Chopra                                                                                1
# Adrian Lyne                                                                                  2
# Agn_�s Varda                                                                                 3
# Agnieszka Holland                                                                            1
# Aki Kaurism__ki                                                                              2
# ...

# %%
movies_df.groupby('director').count()['included_in_1001_book']

# %%
movies_df.sort_values('imdb_rating')
# Out:
#         imdb_id  rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# 1003  tt0138329            NaN            NaN            NaN           NaN
# 820   tt0095485            NaN            NaN            NaN           NaN
# 456   tt0059880            NaN            NaN            NaN           NaN
# 385   tt0054880            NaN            NaN            NaN           NaN
# 550   tt0067810            NaN            NaN            NaN           NaN
# 845   tt0098143            NaN            NaN            NaN           NaN
# 396   tt0056060            NaN            NaN            NaN           NaN
# 463   tt0060511            NaN            NaN            NaN           NaN
# 993   tt0127354            NaN            NaN            NaN           NaN
# 1042  tt0216605            NaN            NaN            NaN           NaN
# 621   tt0073650            NaN            NaN            NaN           NaN
# ...

# %%
movies_df.sort_values('director')
# Out:
#         imdb_id  rank_afc_2007  rank_afc_1998  rank_wga_2005  rank_ss_2012  \
# 931   tt0111845            NaN            NaN            NaN           NaN
# 982   tt0120265            NaN            NaN            NaN           NaN
# 1036  tt0209463            NaN            NaN            NaN           NaN
# 859   tt0100234            NaN            NaN            NaN            42
# 1200  tt2278871            NaN            NaN            NaN           NaN
# 857   tt0099939            NaN            NaN            NaN           NaN
# 35    tt0018192            NaN            NaN            NaN           NaN
# 18    tt0014417            NaN            NaN            NaN           NaN
# 208   tt0040366            NaN            NaN            NaN           NaN
# 941   tt0112870            NaN            NaN            NaN           NaN
# 793   tt0093010            NaN            NaN            NaN           NaN
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import matplotlib

# %%
matplotlib.style.use('ggplot')

# %%
movies_df['imdb_rating'].plot(kind='hist')

# %%
movies_df['year'].plot(kind='hist')

# %%
movies_df.plot(kind='scatter', x='imdb_rating', y='rank_afc_2007')

# %%
movies_df.plot(kind='scatter', x='imdb_rating', y='rank_wga_2005')

# %%
movies_df.query('rank_afc_2007 > 0 and rank_afc_1998 > 0 and rank_wga_2005 > 0 and rank_ss_2012 > 0 and included_in_guardian_list == True')
